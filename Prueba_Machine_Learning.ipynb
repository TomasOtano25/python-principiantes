# %% [markdown]
# <a href="https://colab.research.google.com/github/TomasOtano25/python-principiantes/blob/main/Prueba_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prueba Machine Learning
#
# https://www.kaggle.com/

# %%
import pandas as pd
df = pd.read_csv('/content/android-games.csv')
df.shape
# Out:
# (1730, 15)

# %%
df
# Out:
#       rank                                         title  total ratings  \
# 0        1                Garena Free Fire- World Series       86273129
# 1        2                        PUBG MOBILE - Traverse       37276732
# 2        3                     Mobile Legends: Bang Bang       26663595
# 3        4                                   Brawl Stars       17971552
# 4        5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...    ...                                           ...            ...
# 1725    96                 زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726    97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727    98                  Scrabble® GO - New Word Game         110723
# 1728    99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729   100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
df.describe()
# Out:
#               rank  total ratings  average rating  growth (30 days)  \
# count  1730.000000   1.730000e+03     1730.000000       1730.000000
# mean     50.386705   1.064332e+06        3.908092        321.735896
# std      28.936742   3.429250e+06        0.290973       6018.914507
# min       1.000000   3.299300e+04        2.000000          0.000000
# 25%      25.000000   1.759992e+05        4.000000          0.100000
# 50%      50.000000   4.286065e+05        4.000000          0.500000
# 75%      75.000000   8.837970e+05        4.000000          1.700000
# max     100.000000   8.627313e+07        4.000000     227105.700000
#
#        growth (60 days)        price  5 star ratings  4 star ratings  \
# count       1730.000000  1730.000000    1.730000e+03    1.730000e+03
# mean         122.554971     0.010942    7.622315e+05    1.164366e+05
# std         2253.891703     0.214987    2.538658e+06    3.021631e+05
# min            0.000000     0.000000    1.397500e+04    2.451000e+03
# ...

# %%
df.values
# Out:
# array([[1, 'Garena Free Fire- World Series', 86273129, ..., 2122183,
#         12495915, False],
#        [2, 'PUBG MOBILE - Traverse', 37276732, ..., 809821, 4709492,
#         False],
#        [3, 'Mobile Legends: Bang Bang', 26663595, ..., 713912, 4308998,
#         False],
#        ...,
#        [98, 'Scrabble® GO - New Word Game', 110723, ..., 6688, 12132,
#         False],
#        [99, 'Word Nut: Word Puzzle Games & Crosswords', 109530, ..., 953,
#         2353, False],
#        [100, 'Pinturillo 2', 108917, ..., 6166, 23631, False]],
#       dtype=object)

# %% [markdown]
# # Ejemplo de deportes

# %%
# !pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=6b7f1558a790d4c47ed5a4fc17cbef3fdef9896081a8b5089a8c1e5b72bc0e8a
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib

dataset = pd.read_csv('/content/deportes.csv')

inputs = dataset.drop(columns=['deporte'])
outputs = dataset['deporte']

modelo = DecisionTreeClassifier()
modelo.fit(inputs, outputs)

# joblib.dump(modelo, 'deportes-ml.joblib')

predicciones = modelo.predict([ [1,24], [2,33] ])
predicciones
# Out:
# ['deportes-ml.joblib']

# %%
modelo = joblib.load('/content/deportes-ml.joblib')

predicciones = modelo.predict([ [1,24], [2,33] ])
predicciones
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array(['Football', 'Basket'], dtype=object)
