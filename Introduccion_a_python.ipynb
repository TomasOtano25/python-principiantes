# %% [markdown]
# <a href="https://colab.research.google.com/github/TomasOtano25/python-principiantes/blob/main/Introduccion_a_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('Hola mundo')
# Out:
# Hola mundo

# %%
nombre = 'Lucas'
nombre = 'Pedro'

# %%
print('Hola mundo, soy ' + nombre)
# Out:
# Hola mundo, soy Pedro

# %%
edad = 30

# %%
print('Hola mundo, soy ' + nombre + ' y tengo ' + str(edad) + ' años')
# Out:
# Hola mundo, soy Pedro y tengo 30 años

# %%
texto = 'Hola mundo, soy ' + nombre + ' y tengo ' + str(edad) + ' años'
print(texto)
# Out:
# Hola mundo, soy Pedro y tengo 30 años

# %% [markdown]
# ## Ejercicio 2

# %%
nombre = input("Como te llamas?")
print('Hola ' + nombre)

edad = int(input("Cual es tu edad?"))
if edad >= 18:
  print('Es mayor de edad')
else:
  print('Es menor de edad')
# Out:
# Como te llamas?Tomas
# Hola Tomas
# Cual es tu edad?22
# Es mayor de edad

# %% [markdown]
# ## Ejercicio 3

# %%
nombre = input("Como te llamas?")
print('Hola ' + nombre)

edad = int(input("Cual es tu edad?"))
masDe12 = edad >= 12

respuestaHijoDelDueño = input("Es hijo del dueño?")
esHijoDelDueño = respuestaHijoDelDueño == 'si'

puedaPasar = masDe12 or esHijoDelDueño

if puedaPasar:
  print('Usted puede pasar a la montaña rusa')
else:
  print('No puede pasar')
# Out:
# Como te llamas?Tomas
# Hola Tomas
# Cual es tu edad?13
# Es hijo del dueño?no
# Usted puede pasar a la montaña rusa

# %% [markdown]
# ## Ejercicio 4 - Numero Par o Impar

# %%
numero = int(input("Ingrese un numero: "))

if numero % 2 == 0:
  print('El numero es par')
else:
  print('El numero es impar')
# Out:
# Ingrese un numero: 6
# El numero es par

# %% [markdown]
# ## Ejercicio 5

# %%
def mostrarPrecioFinal(producto, precio, descuento):
  precioFinal = precio - descuento * precio / 100
  print("El precio del " + producto + " es $:" + str(precioFinal))

mostrarPrecioFinal("Pantalon", 40, 20)
# Out:
# El precio del Pantalon es $:32.0
